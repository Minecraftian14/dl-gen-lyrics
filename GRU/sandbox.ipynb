# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip bigru_lyrics.zip
# Out:
# Archive:  bigru_lyrics.zip
#    creating: data/
#    creating: src/
#    creating: src/dataset/
#   inflating: src/dataset/lyrics_dataset.py
#    creating: src/evaluation/
#   inflating: src/evaluation/evaluator.py
#    creating: src/inference/
#   inflating: src/inference/generator.py
#    creating: src/model/
#   inflating: src/model/bigru.py
#    creating: src/preprocessing/
#   inflating: src/preprocessing/annotator.py
#   inflating: src/preprocessing/cleaner.py
#   inflating: src/preprocessing/tokenizer.py
#    creating: src/training/
#   inflating: src/training/trainer.py
#   inflating: ARCHITECTURE.md
#   inflating: config.py
#   inflating: generate.py
#   inflating: preprocess.py
#   inflating: README.md
#   inflating: requirements.txt
#   inflating: train.py

# %%
# !cp /content/drive/MyDrive/song_lyrics.csv /content/data

# %%
# !pip install -q contractions>=0.1.73
# !pip install -q bert-score>=0.3.13
# !pip install mauve-text>=0.3.0

# %%
# !python preprocess.py --data_path data/song_lyrics.csv
# Out:
# 2026-04-20 08:10:41,116 [INFO] __main__ — Loading dataset from data/song_lyrics.csv …
# 2026-04-20 08:10:44,706 [INFO] __main__ — Raw rows: 100002
# 2026-04-20 08:10:44,743 [INFO] __main__ — After language filter (en): 100002 rows
# 2026-04-20 08:10:44,791 [INFO] __main__ — Cleaning lyrics …
# 2026-04-20 08:12:59,776 [INFO] __main__ — After cleaning + length filter: 100002 rows
# 2026-04-20 08:12:59,787 [INFO] __main__ — Annotating (genre tokens + TF-IDF theme extraction) …
# 2026-04-20 08:12:59,787 [INFO] src.preprocessing.annotator — Building genre tokens …
# 2026-04-20 08:12:59,897 [INFO] src.preprocessing.annotator — Fitting TF-IDF on 100002 documents …
# 2026-04-20 08:13:15,932 [INFO] src.preprocessing.annotator — TF-IDF vocabulary size: 10000
# 2026-04-20 08:13:15,935 [INFO] src.preprocessing.annotator — Extracting theme keywords per song (TF-IDF) …
# 2026-04-20 08:14:17,584 [INFO] src.preprocessing.annotator — Building annotated sequences …
# ...

# %%
# !python train.py --output_dir checkpoints/ --epochs 1
# Out:
# 2026-04-20 08:17:35.010718: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776673055.031782    3615 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776673055.039179    3615 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776673055.057582    3615 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python generate.py --checkpoint checkpoints/best_model.pt --start_phrase "i walk alone in" --genre "pop" --num_stanzas 2
# Out:
# 2026-04-20 09:07:23.041440: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776676043.063513   16795 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776676043.070926   16795 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776676043.089736   16795 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
